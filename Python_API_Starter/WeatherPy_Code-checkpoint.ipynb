# %% [markdown]
# # WeatherPy
#
# ---
#
# ##  Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key
from api_keys import geoapify_key

# !pip install citipy

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Out:
# Requirement already satisfied: citipy in c:\users\swati\anaconda3\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in c:\users\swati\anaconda3\lib\site-packages (from citipy) (0.16)

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 596

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Base URL to work off                         
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Counter to go through data
record = 0
sets = 1

# Create DataFrame
weather_df = pd.DataFrame({"City": cities})

weather_df["Country"] = ""
weather_df["Date"] = ""      
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""
weather_df["Cloudiness (%)"] = ""
weather_df["Humidity (%)"] = ""
weather_df["Max Temp (F)"] = ""
weather_df["Wind Speed (mph)"] = ""


# Interate through Cities and retrieve data
print("Beginning Data Retrieval")
print("-----------------------------")


for index, row in weather_df.iterrows():
    
    city = row["City"]
    
    query_url = base_url + "appid=" + weather_api_key + "&q=" + city
    weather_response = requests.get(query_url).json()
 
    try:
        print(f"Processing Record {record}  of Set {sets} | {city}.")
        #print (query_url) 
        weather_df.loc[index, "Country"] = weather_response["sys"]["country"]     
        weather_df.loc[index, "Latitude"] = weather_response["coord"]["lat"]
        weather_df.loc[index, "Longitude"] = weather_response["coord"]["lon"]
        weather_df.loc[index, "Cloudiness (%)"] = weather_response["clouds"]["all"]
        weather_df.loc[index, "Humidity (%)"] = weather_response["main"]["humidity"]
        weather_df.loc[index, "Max Temp (F)"] = 1.8 * (weather_response["main"]["temp_max"] - 273) + 32
        weather_df.loc[index, "Wind Speed (mph)"] = weather_response["wind"]["speed"]
        weather_df.loc[index, "Date"] = datetime.datetime.fromtimestamp(weather_response["dt"])       
    except:
        print(f"City not found...skipping {city}.")
        #print (query_url) 
        
    
    record = record + 1
    if record == 50:
        record = 0
        sets = sets + 1 

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0  of Set 1 | edinburgh of the seven seas.
# City not found...skipping edinburgh of the seven seas.
# Processing Record 1  of Set 1 | port douglas.
# City not found...skipping port douglas.
# Processing Record 2  of Set 1 | wailua homesteads.
# City not found...skipping wailua homesteads.
# Processing Record 3  of Set 1 | invercargill.
# City not found...skipping invercargill.
# Processing Record 4  of Set 1 | tranovaho.
# City not found...skipping tranovaho.
# Processing Record 5  of Set 1 | fisterra.
# City not found...skipping fisterra.
# Processing Record 6  of Set 1 | ust-nera.
# City not found...skipping ust-nera.
# Processing Record 7  of Set 1 | adamstown.
# City not found...skipping adamstown.
# Processing Record 8  of Set 1 | kone.
# City not found...skipping kone.
# Processing Record 9  of Set 1 | selfoss.
# City not found...skipping selfoss.
# Processing Record 10  of Set 1 | phayao.
# City not found...skipping phayao.
# Processing Record 11  of Set 1 | ilulissat.
# City not found...skipping ilulissat.
# Processing Record 12  of Set 1 | georgetown.
# City not found...skipping georgetown.
# Processing Record 13  of Set 1 | vershino-darasunskiy.
# City not found...skipping vershino-darasunskiy.
# Processing Record 14  of Set 1 | nueva gerona.
# City not found...skipping nueva gerona.
# Processing Record 15  of Set 1 | pauini.
# City not found...skipping pauini.
# Processing Record 16  of Set 1 | lihue.
# City not found...skipping lihue.
# Processing Record 17  of Set 1 | thompson.
# City not found...skipping thompson.
# Processing Record 18  of Set 1 | minas de marcona.
# City not found...skipping minas de marcona.
# Processing Record 19  of Set 1 | mel'nikovo.
# City not found...skipping mel'nikovo.
# Processing Record 20  of Set 1 | san fernando.
# City not found...skipping san fernando.
# Processing Record 21  of Set 1 | vel'sk.
# City not found...skipping vel'sk.
# Processing Record 22  of Set 1 | maragogi.
# City not found...skipping maragogi.
# Processing Record 23  of Set 1 | fort bragg.
# City not found...skipping fort bragg.
# Processing Record 24  of Set 1 | albany.
# City not found...skipping albany.
# Processing Record 25  of Set 1 | petropavlovsk-kamchatsky.
# City not found...skipping petropavlovsk-kamchatsky.
# Processing Record 26  of Set 1 | waitangi.
# City not found...skipping waitangi.
# Processing Record 27  of Set 1 | mustafakemalpasa.
# City not found...skipping mustafakemalpasa.
# Processing Record 28  of Set 1 | puerto ayora.
# City not found...skipping puerto ayora.
# Processing Record 29  of Set 1 | scarborough.
# City not found...skipping scarborough.
# Processing Record 30  of Set 1 | blackmans bay.
# City not found...skipping blackmans bay.
# Processing Record 31  of Set 1 | oban.
# City not found...skipping oban.
# Processing Record 32  of Set 1 | hamilton.
# City not found...skipping hamilton.
# Processing Record 33  of Set 1 | grytviken.
# City not found...skipping grytviken.
# Processing Record 34  of Set 1 | mogocha.
# City not found...skipping mogocha.
# Processing Record 35  of Set 1 | yellowknife.
# City not found...skipping yellowknife.
# Processing Record 36  of Set 1 | vryburg.
# City not found...skipping vryburg.
# Processing Record 37  of Set 1 | port-aux-francais.
# City not found...skipping port-aux-francais.
# Processing Record 38  of Set 1 | saint-joseph.
# City not found...skipping saint-joseph.
# Processing Record 39  of Set 1 | summerside.
# City not found...skipping summerside.
# Processing Record 40  of Set 1 | fonadhoo.
# City not found...skipping fonadhoo.
# Processing Record 41  of Set 1 | flying fish cove.
# City not found...skipping flying fish cove.
# Processing Record 42  of Set 1 | taiohae.
# City not found...skipping taiohae.
# Processing Record 43  of Set 1 | tiksi.
# City not found...skipping tiksi.
# Processing Record 44  of Set 1 | dudinka.
# City not found...skipping dudinka.
# Processing Record 45  of Set 1 | bocanda.
# City not found...skipping bocanda.
# Processing Record 46  of Set 1 | virginia.
# City not found...skipping virginia.
# Processing Record 47  of Set 1 | karagandy.
# City not found...skipping karagandy.
# Processing Record 48  of Set 1 | anadyr.
# City not found...skipping anadyr.
# Processing Record 49  of Set 1 | kungsor.
# City not found...skipping kungsor.
# Processing Record 0  of Set 2 | ushuaia.
# City not found...skipping ushuaia.
# Processing Record 1  of Set 2 | badger.
# City not found...skipping badger.
# Processing Record 2  of Set 2 | ribeira grande.
# City not found...skipping ribeira grande.
# Processing Record 3  of Set 2 | al khafji.
# City not found...skipping al khafji.
# Processing Record 4  of Set 2 | enewetak.
# City not found...skipping enewetak.
# Processing Record 5  of Set 2 | rivne.
# City not found...skipping rivne.
# Processing Record 6  of Set 2 | de panne.
# City not found...skipping de panne.
# Processing Record 7  of Set 2 | constantia.
# City not found...skipping constantia.
# Processing Record 8  of Set 2 | bethel.
# City not found...skipping bethel.
# Processing Record 9  of Set 2 | atafu village.
# City not found...skipping atafu village.
# Processing Record 10  of Set 2 | gandajika.
# City not found...skipping gandajika.
# Processing Record 11  of Set 2 | miyaly.
# City not found...skipping miyaly.
# Processing Record 12  of Set 2 | avarua.
# City not found...skipping avarua.
# Processing Record 13  of Set 2 | mezgor'e.
# City not found...skipping mezgor'e.
# Processing Record 14  of Set 2 | arkhangel'sk.
# City not found...skipping arkhangel'sk.
# Processing Record 15  of Set 2 | vila do maio.
# City not found...skipping vila do maio.
# Processing Record 16  of Set 2 | terrace.
# City not found...skipping terrace.
# Processing Record 17  of Set 2 | new norfolk.
# City not found...skipping new norfolk.
# Processing Record 18  of Set 2 | fortaleza.
# City not found...skipping fortaleza.
# Processing Record 19  of Set 2 | fort wellington.
# City not found...skipping fort wellington.
# Processing Record 20  of Set 2 | visby.
# City not found...skipping visby.
# Processing Record 21  of Set 2 | mthatha.
# City not found...skipping mthatha.
# Processing Record 22  of Set 2 | westport.
# City not found...skipping westport.
# Processing Record 23  of Set 2 | redencao.
# City not found...skipping redencao.
# Processing Record 24  of Set 2 | svetlyy yar.
# City not found...skipping svetlyy yar.
# Processing Record 25  of Set 2 | kiknur.
# City not found...skipping kiknur.
# Processing Record 26  of Set 2 | mena.
# City not found...skipping mena.
# Processing Record 27  of Set 2 | carloforte.
# City not found...skipping carloforte.
# Processing Record 28  of Set 2 | whitehorse.
# City not found...skipping whitehorse.
# Processing Record 29  of Set 2 | kahna nau.
# City not found...skipping kahna nau.
# Processing Record 30  of Set 2 | nueva esperanza.
# City not found...skipping nueva esperanza.
# Processing Record 31  of Set 2 | mount gambier.
# City not found...skipping mount gambier.
# Processing Record 32  of Set 2 | emerald.
# City not found...skipping emerald.
# Processing Record 33  of Set 2 | olonkinbyen.
# City not found...skipping olonkinbyen.
# Processing Record 34  of Set 2 | kelibia.
# City not found...skipping kelibia.
# Processing Record 35  of Set 2 | khovd.
# City not found...skipping khovd.
# Processing Record 36  of Set 2 | dungarpur.
# City not found...skipping dungarpur.
# Processing Record 37  of Set 2 | chirpan.
# City not found...skipping chirpan.
# Processing Record 38  of Set 2 | miyako.
# City not found...skipping miyako.
# Processing Record 39  of Set 2 | puerto natales.
# City not found...skipping puerto natales.
# Processing Record 40  of Set 2 | jamestown.
# City not found...skipping jamestown.
# Processing Record 41  of Set 2 | mildura.
# City not found...skipping mildura.
# Processing Record 42  of Set 2 | aasiaat.
# City not found...skipping aasiaat.
# Processing Record 43  of Set 2 | klyuchi.
# City not found...skipping klyuchi.
# Processing Record 44  of Set 2 | gidam.
# City not found...skipping gidam.
# Processing Record 45  of Set 2 | stanley.
# City not found...skipping stanley.
# Processing Record 46  of Set 2 | valparaiso.
# City not found...skipping valparaiso.
# Processing Record 47  of Set 2 | papao.
# City not found...skipping papao.
# Processing Record 48  of Set 2 | el alto.
# City not found...skipping el alto.
# Processing Record 49  of Set 2 | brisas de zicatela.
# City not found...skipping brisas de zicatela.
# Processing Record 0  of Set 3 | aleg.
# City not found...skipping aleg.
# Processing Record 1  of Set 3 | weno.
# City not found...skipping weno.
# Processing Record 2  of Set 3 | ha tinh.
# City not found...skipping ha tinh.
# Processing Record 3  of Set 3 | leninsk.
# City not found...skipping leninsk.
# Processing Record 4  of Set 3 | kristiansund.
# City not found...skipping kristiansund.
# Processing Record 5  of Set 3 | bredasdorp.
# City not found...skipping bredasdorp.
# Processing Record 6  of Set 3 | belmonte.
# City not found...skipping belmonte.
# Processing Record 7  of Set 3 | batibo.
# City not found...skipping batibo.
# Processing Record 8  of Set 3 | sechura.
# City not found...skipping sechura.
# Processing Record 9  of Set 3 | alofi.
# City not found...skipping alofi.
# Processing Record 10  of Set 3 | barsukovskaya.
# City not found...skipping barsukovskaya.
# Processing Record 11  of Set 3 | talnakh.
# City not found...skipping talnakh.
# Processing Record 12  of Set 3 | arraial do cabo.
# City not found...skipping arraial do cabo.
# Processing Record 13  of Set 3 | balsas.
# City not found...skipping balsas.
# Processing Record 14  of Set 3 | margaret river.
# City not found...skipping margaret river.
# Processing Record 15  of Set 3 | blackfoot.
# City not found...skipping blackfoot.
# Processing Record 16  of Set 3 | sur.
# City not found...skipping sur.
# Processing Record 17  of Set 3 | broken hill.
# City not found...skipping broken hill.
# Processing Record 18  of Set 3 | tual.
# City not found...skipping tual.
# Processing Record 19  of Set 3 | arawa.
# City not found...skipping arawa.
# Processing Record 20  of Set 3 | saint-pierre.
# City not found...skipping saint-pierre.
# Processing Record 21  of Set 3 | bukittinggi.
# City not found...skipping bukittinggi.
# Processing Record 22  of Set 3 | plesetsk.
# City not found...skipping plesetsk.
# Processing Record 23  of Set 3 | nagqu.
# City not found...skipping nagqu.
# Processing Record 24  of Set 3 | sant feliu de guixols.
# City not found...skipping sant feliu de guixols.
# Processing Record 25  of Set 3 | kohtla-jarve.
# City not found...skipping kohtla-jarve.
# Processing Record 26  of Set 3 | port mathurin.
# City not found...skipping port mathurin.
# Processing Record 27  of Set 3 | anju.
# City not found...skipping anju.
# Processing Record 28  of Set 3 | sitka.
# City not found...skipping sitka.
# Processing Record 29  of Set 3 | namibe.
# City not found...skipping namibe.
# Processing Record 30  of Set 3 | karaton.
# City not found...skipping karaton.
# Processing Record 31  of Set 3 | quellon.
# City not found...skipping quellon.
# Processing Record 32  of Set 3 | utrik.
# City not found...skipping utrik.
# Processing Record 33  of Set 3 | port elizabeth.
# City not found...skipping port elizabeth.
# Processing Record 34  of Set 3 | jinzhou.
# City not found...skipping jinzhou.
# Processing Record 35  of Set 3 | santa cruz.
# City not found...skipping santa cruz.
# Processing Record 36  of Set 3 | comodoro rivadavia.
# City not found...skipping comodoro rivadavia.
# Processing Record 37  of Set 3 | north battleford.
# City not found...skipping north battleford.
# Processing Record 38  of Set 3 | fale old settlement.
# City not found...skipping fale old settlement.
# Processing Record 39  of Set 3 | port lincoln.
# City not found...skipping port lincoln.
# Processing Record 40  of Set 3 | adigrat.
# City not found...skipping adigrat.
# Processing Record 41  of Set 3 | kavieng.
# City not found...skipping kavieng.
# Processing Record 42  of Set 3 | longyearbyen.
# City not found...skipping longyearbyen.
# Processing Record 43  of Set 3 | tinajo.
# City not found...skipping tinajo.
# Processing Record 44  of Set 3 | siwa oasis.
# City not found...skipping siwa oasis.
# Processing Record 45  of Set 3 | kapa'a.
# City not found...skipping kapa'a.
# Processing Record 46  of Set 3 | portland.
# City not found...skipping portland.
# Processing Record 47  of Set 3 | thames.
# City not found...skipping thames.
# Processing Record 48  of Set 3 | rattvik.
# City not found...skipping rattvik.
# Processing Record 49  of Set 3 | queenstown.
# City not found...skipping queenstown.
# Processing Record 0  of Set 4 | alice springs.
# City not found...skipping alice springs.
# Processing Record 1  of Set 4 | okakarara.
# City not found...skipping okakarara.
# Processing Record 2  of Set 4 | lakes.
# City not found...skipping lakes.
# Processing Record 3  of Set 4 | iqaluit.
# City not found...skipping iqaluit.
# Processing Record 4  of Set 4 | udachny.
# City not found...skipping udachny.
# Processing Record 5  of Set 4 | altayskoye.
# City not found...skipping altayskoye.
# Processing Record 6  of Set 4 | amarante do maranhao.
# City not found...skipping amarante do maranhao.
# Processing Record 7  of Set 4 | mata-utu.
# City not found...skipping mata-utu.
# Processing Record 8  of Set 4 | lijiang.
# City not found...skipping lijiang.
# Processing Record 9  of Set 4 | tofol.
# City not found...skipping tofol.
# Processing Record 10  of Set 4 | charlottetown.
# City not found...skipping charlottetown.
# Processing Record 11  of Set 4 | ciudad insurgentes.
# City not found...skipping ciudad insurgentes.
# Processing Record 12  of Set 4 | ko lanta.
# City not found...skipping ko lanta.
# Processing Record 13  of Set 4 | luderitz.
# City not found...skipping luderitz.
# Processing Record 14  of Set 4 | ulsteinvik.
# City not found...skipping ulsteinvik.
# Processing Record 15  of Set 4 | punta arenas.
# City not found...skipping punta arenas.
# Processing Record 16  of Set 4 | sonsorol village.
# City not found...skipping sonsorol village.
# Processing Record 17  of Set 4 | ndele.
# City not found...skipping ndele.
# Processing Record 18  of Set 4 | ciudad bolivar.
# City not found...skipping ciudad bolivar.
# Processing Record 19  of Set 4 | lembar.
# City not found...skipping lembar.
# Processing Record 20  of Set 4 | iskateley.
# City not found...skipping iskateley.
# Processing Record 21  of Set 4 | lata.
# City not found...skipping lata.
# Processing Record 22  of Set 4 | hawaiian paradise park.
# City not found...skipping hawaiian paradise park.
# Processing Record 23  of Set 4 | port alfred.
# City not found...skipping port alfred.
# Processing Record 24  of Set 4 | colonia.
# City not found...skipping colonia.
# Processing Record 25  of Set 4 | elmendorf air force base.
# City not found...skipping elmendorf air force base.
# Processing Record 26  of Set 4 | verkhnevilyuysk.
# City not found...skipping verkhnevilyuysk.
# Processing Record 27  of Set 4 | west island.
# City not found...skipping west island.
# Processing Record 28  of Set 4 | fort st. john.
# City not found...skipping fort st. john.
# Processing Record 29  of Set 4 | komsomol'sk.
# City not found...skipping komsomol'sk.
# Processing Record 30  of Set 4 | lebanon.
# City not found...skipping lebanon.
# Processing Record 31  of Set 4 | kruisfontein.
# City not found...skipping kruisfontein.
# Processing Record 32  of Set 4 | mumford.
# City not found...skipping mumford.
# Processing Record 33  of Set 4 | colac.
# City not found...skipping colac.
# Processing Record 34  of Set 4 | tosontsengel.
# City not found...skipping tosontsengel.
# Processing Record 35  of Set 4 | karratha.
# City not found...skipping karratha.
# Processing Record 36  of Set 4 | chok chai.
# City not found...skipping chok chai.
# Processing Record 37  of Set 4 | wanning.
# City not found...skipping wanning.
# Processing Record 38  of Set 4 | darwin.
# City not found...skipping darwin.
# Processing Record 39  of Set 4 | al bawiti.
# City not found...skipping al bawiti.
# Processing Record 40  of Set 4 | bilibino.
# City not found...skipping bilibino.
# Processing Record 41  of Set 4 | kyabe.
# City not found...skipping kyabe.
# Processing Record 42  of Set 4 | las heras.
# City not found...skipping las heras.
# Processing Record 43  of Set 4 | lakhipur.
# City not found...skipping lakhipur.
# Processing Record 44  of Set 4 | hastings.
# City not found...skipping hastings.
# Processing Record 45  of Set 4 | aioun.
# City not found...skipping aioun.
# Processing Record 46  of Set 4 | vyalikaya byerastavitsa.
# City not found...skipping vyalikaya byerastavitsa.
# Processing Record 47  of Set 4 | kili.
# City not found...skipping kili.
# Processing Record 48  of Set 4 | vilyuchinsk.
# City not found...skipping vilyuchinsk.
# Processing Record 49  of Set 4 | kavaratti.
# City not found...skipping kavaratti.
# Processing Record 0  of Set 5 | san antonio de pale.
# City not found...skipping san antonio de pale.
# Processing Record 1  of Set 5 | barah.
# City not found...skipping barah.
# Processing Record 2  of Set 5 | veraval.
# City not found...skipping veraval.
# Processing Record 3  of Set 5 | la'ie.
# City not found...skipping la'ie.
# Processing Record 4  of Set 5 | road town.
# City not found...skipping road town.
# Processing Record 5  of Set 5 | undurkhaan.
# City not found...skipping undurkhaan.
# Processing Record 6  of Set 5 | tolanaro.
# City not found...skipping tolanaro.
# Processing Record 7  of Set 5 | taroa.
# City not found...skipping taroa.
# Processing Record 8  of Set 5 | neuruppin.
# City not found...skipping neuruppin.
# Processing Record 9  of Set 5 | saldanha.
# City not found...skipping saldanha.
# Processing Record 10  of Set 5 | kyzyl-burun.
# City not found...skipping kyzyl-burun.
# Processing Record 11  of Set 5 | bechar.
# City not found...skipping bechar.
# Processing Record 12  of Set 5 | waingapu.
# City not found...skipping waingapu.
# Processing Record 13  of Set 5 | collie.
# City not found...skipping collie.
# Processing Record 14  of Set 5 | andergrove.
# City not found...skipping andergrove.
# Processing Record 15  of Set 5 | trincomalee.
# City not found...skipping trincomalee.
# Processing Record 16  of Set 5 | banjarmasin.
# City not found...skipping banjarmasin.
# Processing Record 17  of Set 5 | alesund.
# City not found...skipping alesund.
# Processing Record 18  of Set 5 | miyazu.
# City not found...skipping miyazu.
# Processing Record 19  of Set 5 | mount pleasant.
# City not found...skipping mount pleasant.
# Processing Record 20  of Set 5 | renon - ritten.
# City not found...skipping renon - ritten.
# Processing Record 21  of Set 5 | nar'yan-mar.
# City not found...skipping nar'yan-mar.
# Processing Record 22  of Set 5 | geraldton.
# City not found...skipping geraldton.
# Processing Record 23  of Set 5 | newman.
# City not found...skipping newman.
# Processing Record 24  of Set 5 | ciudad lazaro cardenas.
# City not found...skipping ciudad lazaro cardenas.
# Processing Record 25  of Set 5 | olyokminsk.
# City not found...skipping olyokminsk.
# Processing Record 26  of Set 5 | malango.
# City not found...skipping malango.
# Processing Record 27  of Set 5 | bandar-e anzali.
# City not found...skipping bandar-e anzali.
# Processing Record 28  of Set 5 | vorgashor.
# City not found...skipping vorgashor.
# Processing Record 29  of Set 5 | sikonge.
# City not found...skipping sikonge.
# Processing Record 30  of Set 5 | chegdomyn.
# City not found...skipping chegdomyn.
# Processing Record 31  of Set 5 | watford city.
# City not found...skipping watford city.
# Processing Record 32  of Set 5 | papatowai.
# City not found...skipping papatowai.
# Processing Record 33  of Set 5 | prince rupert.
# City not found...skipping prince rupert.
# Processing Record 34  of Set 5 | antofagasta.
# City not found...skipping antofagasta.
# Processing Record 35  of Set 5 | vingt cinq.
# City not found...skipping vingt cinq.
# Processing Record 36  of Set 5 | yanam.
# City not found...skipping yanam.
# Processing Record 37  of Set 5 | kapuskasing.
# City not found...skipping kapuskasing.
# Processing Record 38  of Set 5 | kataragama.
# City not found...skipping kataragama.
# Processing Record 39  of Set 5 | san julian.
# City not found...skipping san julian.
# Processing Record 40  of Set 5 | aykhal.
# City not found...skipping aykhal.
# Processing Record 41  of Set 5 | camana.
# City not found...skipping camana.
# Processing Record 42  of Set 5 | mount isa.
# City not found...skipping mount isa.
# Processing Record 43  of Set 5 | chaplygin.
# City not found...skipping chaplygin.
# Processing Record 44  of Set 5 | chibougamau.
# City not found...skipping chibougamau.
# Processing Record 45  of Set 5 | lorengau.
# City not found...skipping lorengau.
# Processing Record 46  of Set 5 | uturoa.
# City not found...skipping uturoa.
# Processing Record 47  of Set 5 | tirebolu.
# City not found...skipping tirebolu.
# Processing Record 48  of Set 5 | la passe.
# City not found...skipping la passe.
# Processing Record 49  of Set 5 | nouadhibou.
# City not found...skipping nouadhibou.
# Processing Record 0  of Set 6 | zangguy.
# City not found...skipping zangguy.
# Processing Record 1  of Set 6 | afaahiti.
# City not found...skipping afaahiti.
# Processing Record 2  of Set 6 | kendari.
# City not found...skipping kendari.
# Processing Record 3  of Set 6 | kailua-kona.
# City not found...skipping kailua-kona.
# Processing Record 4  of Set 6 | lebu.
# City not found...skipping lebu.
# Processing Record 5  of Set 6 | hyderabad.
# City not found...skipping hyderabad.
# Processing Record 6  of Set 6 | willemstad.
# City not found...skipping willemstad.
# Processing Record 7  of Set 6 | touros.
# City not found...skipping touros.
# Processing Record 8  of Set 6 | dosso.
# City not found...skipping dosso.
# Processing Record 9  of Set 6 | araioses.
# City not found...skipping araioses.
# Processing Record 10  of Set 6 | al mindak.
# City not found...skipping al mindak.
# Processing Record 11  of Set 6 | saipan.
# City not found...skipping saipan.
# Processing Record 12  of Set 6 | albisola marina.
# City not found...skipping albisola marina.
# Processing Record 13  of Set 6 | ambon.
# City not found...skipping ambon.
# Processing Record 14  of Set 6 | yeppoon.
# City not found...skipping yeppoon.
# Processing Record 15  of Set 6 | sinop.
# City not found...skipping sinop.
# Processing Record 16  of Set 6 | valdivia.
# City not found...skipping valdivia.
# Processing Record 17  of Set 6 | kingston.
# City not found...skipping kingston.
# Processing Record 18  of Set 6 | montepuez.
# City not found...skipping montepuez.
# Processing Record 19  of Set 6 | crane.
# City not found...skipping crane.
# Processing Record 20  of Set 6 | golfito.
# City not found...skipping golfito.
# Processing Record 21  of Set 6 | tangier.
# City not found...skipping tangier.
# Processing Record 22  of Set 6 | natal.
# City not found...skipping natal.
# Processing Record 23  of Set 6 | dunyamalilar.
# City not found...skipping dunyamalilar.
# Processing Record 24  of Set 6 | hermanus.
# City not found...skipping hermanus.
# Processing Record 25  of Set 6 | an nuhud.
# City not found...skipping an nuhud.
# Processing Record 26  of Set 6 | acapulco de juarez.
# City not found...skipping acapulco de juarez.
# Processing Record 27  of Set 6 | 'ohonua.
# City not found...skipping 'ohonua.
# Processing Record 28  of Set 6 | sonoita.
# City not found...skipping sonoita.
# Processing Record 29  of Set 6 | eureka.
# City not found...skipping eureka.
# Processing Record 30  of Set 6 | tacuarembo.
# City not found...skipping tacuarembo.
# Processing Record 31  of Set 6 | qaqortoq.
# City not found...skipping qaqortoq.
# Processing Record 32  of Set 6 | yaren.
# City not found...skipping yaren.
# Processing Record 33  of Set 6 | carnarvon.
# City not found...skipping carnarvon.
# Processing Record 34  of Set 6 | moyynkum.
# City not found...skipping moyynkum.
# Processing Record 35  of Set 6 | korla.
# City not found...skipping korla.
# Processing Record 36  of Set 6 | nizhniy odes.
# City not found...skipping nizhniy odes.
# Processing Record 37  of Set 6 | lompoc.
# City not found...skipping lompoc.
# Processing Record 38  of Set 6 | labrador city.
# City not found...skipping labrador city.
# Processing Record 39  of Set 6 | parkersburg.
# City not found...skipping parkersburg.
# Processing Record 40  of Set 6 | cuatro cienegas de carranza.
# City not found...skipping cuatro cienegas de carranza.
# Processing Record 41  of Set 6 | lhuentse.
# City not found...skipping lhuentse.
# Processing Record 42  of Set 6 | college.
# City not found...skipping college.
# Processing Record 43  of Set 6 | aginskoye.
# City not found...skipping aginskoye.
# Processing Record 44  of Set 6 | ar rutbah.
# City not found...skipping ar rutbah.
# Processing Record 45  of Set 6 | taguatinga.
# City not found...skipping taguatinga.
# Processing Record 46  of Set 6 | catanzaro.
# City not found...skipping catanzaro.
# Processing Record 47  of Set 6 | kodiak.
# City not found...skipping kodiak.
# Processing Record 48  of Set 6 | taulaga.
# City not found...skipping taulaga.
# Processing Record 49  of Set 6 | yoichi.
# City not found...skipping yoichi.
# Processing Record 0  of Set 7 | holualoa.
# City not found...skipping holualoa.
# Processing Record 1  of Set 7 | nadym.
# City not found...skipping nadym.
# Processing Record 2  of Set 7 | ettrick.
# City not found...skipping ettrick.
# Processing Record 3  of Set 7 | west bay.
# City not found...skipping west bay.
# Processing Record 4  of Set 7 | awjilah.
# City not found...skipping awjilah.
# Processing Record 5  of Set 7 | sao joao da barra.
# City not found...skipping sao joao da barra.
# Processing Record 6  of Set 7 | tirupparangunram.
# City not found...skipping tirupparangunram.
# Processing Record 7  of Set 7 | narasannapeta.
# City not found...skipping narasannapeta.
# Processing Record 8  of Set 7 | praia da vitoria.
# City not found...skipping praia da vitoria.
# Processing Record 9  of Set 7 | dwarka.
# City not found...skipping dwarka.
# Processing Record 10  of Set 7 | coquimbo.
# City not found...skipping coquimbo.
# Processing Record 11  of Set 7 | andreapol'.
# City not found...skipping andreapol'.
# Processing Record 12  of Set 7 | belle fourche.
# City not found...skipping belle fourche.
# Processing Record 13  of Set 7 | puerto san carlos.
# City not found...skipping puerto san carlos.
# Processing Record 14  of Set 7 | dingcheng.
# City not found...skipping dingcheng.
# Processing Record 15  of Set 7 | thunder bay.
# City not found...skipping thunder bay.
# Processing Record 16  of Set 7 | jayapura.
# City not found...skipping jayapura.
# Processing Record 17  of Set 7 | fortuna.
# City not found...skipping fortuna.
# Processing Record 18  of Set 7 | pampa.
# City not found...skipping pampa.
# Processing Record 19  of Set 7 | puerto aysen.
# City not found...skipping puerto aysen.
# Processing Record 20  of Set 7 | palmer.
# City not found...skipping palmer.
# Processing Record 21  of Set 7 | puerto lempira.
# City not found...skipping puerto lempira.
# Processing Record 22  of Set 7 | remire-montjoly.
# City not found...skipping remire-montjoly.
# Processing Record 23  of Set 7 | borogontsy.
# City not found...skipping borogontsy.
# Processing Record 24  of Set 7 | fuxin.
# City not found...skipping fuxin.
# Processing Record 25  of Set 7 | sengiley.
# City not found...skipping sengiley.
# Processing Record 26  of Set 7 | rongelap.
# City not found...skipping rongelap.
# Processing Record 27  of Set 7 | dhuusamarreeb.
# City not found...skipping dhuusamarreeb.
# Processing Record 28  of Set 7 | cidreira.
# City not found...skipping cidreira.
# Processing Record 29  of Set 7 | port augusta.
# City not found...skipping port augusta.
# Processing Record 30  of Set 7 | argo.
# City not found...skipping argo.
# Processing Record 31  of Set 7 | acarau.
# City not found...skipping acarau.
# Processing Record 32  of Set 7 | kudahuvadhoo.
# City not found...skipping kudahuvadhoo.
# Processing Record 33  of Set 7 | praia.
# City not found...skipping praia.
# Processing Record 34  of Set 7 | tortoli.
# City not found...skipping tortoli.
# Processing Record 35  of Set 7 | shenjiamen.
# City not found...skipping shenjiamen.
# Processing Record 36  of Set 7 | north ward.
# City not found...skipping north ward.
# Processing Record 37  of Set 7 | lethem.
# City not found...skipping lethem.
# Processing Record 38  of Set 7 | la gi.
# City not found...skipping la gi.
# Processing Record 39  of Set 7 | kutum.
# City not found...skipping kutum.
# Processing Record 40  of Set 7 | isafjordur.
# City not found...skipping isafjordur.
# Processing Record 41  of Set 7 | mahenge.
# City not found...skipping mahenge.
# Processing Record 42  of Set 7 | kostinbrod.
# City not found...skipping kostinbrod.
# Processing Record 43  of Set 7 | lib.
# City not found...skipping lib.
# Processing Record 44  of Set 7 | zhatay.
# City not found...skipping zhatay.
# Processing Record 45  of Set 7 | carupano.
# City not found...skipping carupano.
# Processing Record 46  of Set 7 | hinthada.
# City not found...skipping hinthada.
# Processing Record 47  of Set 7 | dunedin.
# City not found...skipping dunedin.
# Processing Record 48  of Set 7 | amos.
# City not found...skipping amos.
# Processing Record 49  of Set 7 | sullivan.
# City not found...skipping sullivan.
# Processing Record 0  of Set 8 | vadso.
# City not found...skipping vadso.
# Processing Record 1  of Set 8 | keflavik.
# City not found...skipping keflavik.
# Processing Record 2  of Set 8 | moshi.
# City not found...skipping moshi.
# Processing Record 3  of Set 8 | happy valley-goose bay.
# City not found...skipping happy valley-goose bay.
# Processing Record 4  of Set 8 | isla aguada.
# City not found...skipping isla aguada.
# Processing Record 5  of Set 8 | yichang.
# City not found...skipping yichang.
# Processing Record 6  of Set 8 | palikir - national government center.
# City not found...skipping palikir - national government center.
# Processing Record 7  of Set 8 | manicore.
# City not found...skipping manicore.
# Processing Record 8  of Set 8 | kolokani.
# City not found...skipping kolokani.
# Processing Record 9  of Set 8 | ruidoso.
# City not found...skipping ruidoso.
# Processing Record 10  of Set 8 | dryden.
# City not found...skipping dryden.
# Processing Record 11  of Set 8 | st. john's.
# City not found...skipping st. john's.
# Processing Record 12  of Set 8 | nova sintra.
# City not found...skipping nova sintra.
# Processing Record 13  of Set 8 | illizi.
# City not found...skipping illizi.
# Processing Record 14  of Set 8 | devinuwara.
# City not found...skipping devinuwara.
# Processing Record 15  of Set 8 | sabang.
# City not found...skipping sabang.
# Processing Record 16  of Set 8 | surgana.
# City not found...skipping surgana.
# Processing Record 17  of Set 8 | dadonghai.
# City not found...skipping dadonghai.
# Processing Record 18  of Set 8 | fomboni.
# City not found...skipping fomboni.
# Processing Record 19  of Set 8 | brookings.
# City not found...skipping brookings.
# Processing Record 20  of Set 8 | luanda.
# City not found...skipping luanda.
# Processing Record 21  of Set 8 | katsuren-haebaru.
# City not found...skipping katsuren-haebaru.
# Processing Record 22  of Set 8 | esil.
# City not found...skipping esil.
# Processing Record 23  of Set 8 | butte.
# City not found...skipping butte.
# Processing Record 24  of Set 8 | cable beach.
# City not found...skipping cable beach.
# Processing Record 25  of Set 8 | belyy yar.
# City not found...skipping belyy yar.
# Processing Record 26  of Set 8 | san juan.
# City not found...skipping san juan.
# Processing Record 27  of Set 8 | starke.
# City not found...skipping starke.
# Processing Record 28  of Set 8 | arteche.
# City not found...skipping arteche.
# Processing Record 29  of Set 8 | antalaha.
# City not found...skipping antalaha.
# Processing Record 30  of Set 8 | ol'gino.
# City not found...skipping ol'gino.
# Processing Record 31  of Set 8 | renk.
# City not found...skipping renk.
# Processing Record 32  of Set 8 | tralee.
# City not found...skipping tralee.
# Processing Record 33  of Set 8 | susuman.
# City not found...skipping susuman.
# Processing Record 34  of Set 8 | rosarito.
# City not found...skipping rosarito.
# Processing Record 35  of Set 8 | floro.
# City not found...skipping floro.
# Processing Record 36  of Set 8 | christchurch.
# City not found...skipping christchurch.
# Processing Record 37  of Set 8 | moose jaw.
# City not found...skipping moose jaw.
# Processing Record 38  of Set 8 | tindouf.
# City not found...skipping tindouf.
# Processing Record 39  of Set 8 | tsiombe.
# City not found...skipping tsiombe.
# Processing Record 40  of Set 8 | myshkin.
# City not found...skipping myshkin.
# Processing Record 41  of Set 8 | monte aprazivel.
# City not found...skipping monte aprazivel.
# Processing Record 42  of Set 8 | filey.
# City not found...skipping filey.
# Processing Record 43  of Set 8 | chonchi.
# City not found...skipping chonchi.
# Processing Record 44  of Set 8 | nuuk.
# City not found...skipping nuuk.
# Processing Record 45  of Set 8 | tvoroyri.
# City not found...skipping tvoroyri.
# Processing Record 46  of Set 8 | mahibadhoo.
# City not found...skipping mahibadhoo.
# Processing Record 47  of Set 8 | pisco.
# City not found...skipping pisco.
# Processing Record 48  of Set 8 | tokar.
# City not found...skipping tokar.
# Processing Record 49  of Set 8 | colby.
# City not found...skipping colby.
# Processing Record 0  of Set 9 | mossel bay.
# City not found...skipping mossel bay.
# Processing Record 1  of Set 9 | digora.
# City not found...skipping digora.
# Processing Record 2  of Set 9 | sao filipe.
# City not found...skipping sao filipe.
# Processing Record 3  of Set 9 | vizinga.
# City not found...skipping vizinga.
# Processing Record 4  of Set 9 | howrah.
# City not found...skipping howrah.
# Processing Record 5  of Set 9 | tongliao.
# City not found...skipping tongliao.
# Processing Record 6  of Set 9 | ancud.
# City not found...skipping ancud.
# Processing Record 7  of Set 9 | auki.
# City not found...skipping auki.
# Processing Record 8  of Set 9 | kirovskiy.
# City not found...skipping kirovskiy.
# Processing Record 9  of Set 9 | bac lieu.
# City not found...skipping bac lieu.
# Processing Record 10  of Set 9 | rio grande.
# City not found...skipping rio grande.
# Processing Record 11  of Set 9 | laojunmiao.
# City not found...skipping laojunmiao.
# Processing Record 12  of Set 9 | polyarnyy.
# City not found...skipping polyarnyy.
# Processing Record 13  of Set 9 | am djarass.
# City not found...skipping am djarass.
# Processing Record 14  of Set 9 | fada.
# City not found...skipping fada.
# Processing Record 15  of Set 9 | hithadhoo.
# City not found...skipping hithadhoo.
# Processing Record 16  of Set 9 | san patricio.
# City not found...skipping san patricio.
# Processing Record 17  of Set 9 | umm kaddadah.
# City not found...skipping umm kaddadah.
# Processing Record 18  of Set 9 | st. paul.
# City not found...skipping st. paul.
# Processing Record 19  of Set 9 | cannonvale.
# City not found...skipping cannonvale.
# Processing Record 20  of Set 9 | lerwick.
# City not found...skipping lerwick.
# Processing Record 21  of Set 9 | tucuma.
# City not found...skipping tucuma.
# Processing Record 22  of Set 9 | dzhambeyty.
# City not found...skipping dzhambeyty.
# Processing Record 23  of Set 9 | pacific grove.
# City not found...skipping pacific grove.
# Processing Record 24  of Set 9 | ust'-ilimsk.
# City not found...skipping ust'-ilimsk.
# Processing Record 25  of Set 9 | catabola.
# City not found...skipping catabola.
# Processing Record 26  of Set 9 | doctor mora.
# City not found...skipping doctor mora.
# Processing Record 27  of Set 9 | banikoara.
# City not found...skipping banikoara.
# Processing Record 28  of Set 9 | chui.
# City not found...skipping chui.
# Processing Record 29  of Set 9 | tura.
# City not found...skipping tura.
# Processing Record 30  of Set 9 | apiai.
# City not found...skipping apiai.
# Processing Record 31  of Set 9 | clinton.
# City not found...skipping clinton.
# Processing Record 32  of Set 9 | palu.
# City not found...skipping palu.
# Processing Record 33  of Set 9 | kerikeri.
# City not found...skipping kerikeri.
# Processing Record 34  of Set 9 | mejit.
# City not found...skipping mejit.
# Processing Record 35  of Set 9 | suizhou.
# City not found...skipping suizhou.
# Processing Record 36  of Set 9 | barra velha.
# City not found...skipping barra velha.
# Processing Record 37  of Set 9 | zheleznogorsk.
# City not found...skipping zheleznogorsk.
# Processing Record 38  of Set 9 | songea.
# City not found...skipping songea.
# Processing Record 39  of Set 9 | sychevka.
# City not found...skipping sychevka.
# Processing Record 40  of Set 9 | yinchuan.
# City not found...skipping yinchuan.
# Processing Record 41  of Set 9 | sisimiut.
# City not found...skipping sisimiut.
# Processing Record 42  of Set 9 | pundong.
# City not found...skipping pundong.
# Processing Record 43  of Set 9 | tazovsky.
# City not found...skipping tazovsky.
# Processing Record 44  of Set 9 | levuka.
# City not found...skipping levuka.
# Processing Record 45  of Set 9 | yuzhno-kurilsk.
# City not found...skipping yuzhno-kurilsk.
# Processing Record 46  of Set 9 | princeville.
# City not found...skipping princeville.
# Processing Record 47  of Set 9 | berriane.
# City not found...skipping berriane.
# Processing Record 48  of Set 9 | mingguang.
# City not found...skipping mingguang.
# Processing Record 49  of Set 9 | haiku-pauwela.
# City not found...skipping haiku-pauwela.
# Processing Record 0  of Set 10 | san martin.
# City not found...skipping san martin.
# Processing Record 1  of Set 10 | qamdo.
# City not found...skipping qamdo.
# Processing Record 2  of Set 10 | mancio lima.
# City not found...skipping mancio lima.
# Processing Record 3  of Set 10 | dagomys.
# City not found...skipping dagomys.
# Processing Record 4  of Set 10 | mugia.
# City not found...skipping mugia.
# Processing Record 5  of Set 10 | shiqian.
# City not found...skipping shiqian.
# Processing Record 6  of Set 10 | napier.
# City not found...skipping napier.
# Processing Record 7  of Set 10 | taltal.
# City not found...skipping taltal.
# Processing Record 8  of Set 10 | ta`u.
# City not found...skipping ta`u.
# Processing Record 9  of Set 10 | nizhniy kuranakh.
# City not found...skipping nizhniy kuranakh.
# Processing Record 10  of Set 10 | pinon hills.
# City not found...skipping pinon hills.
# Processing Record 11  of Set 10 | plettenberg bay.
# City not found...skipping plettenberg bay.
# Processing Record 12  of Set 10 | koksovyy.
# City not found...skipping koksovyy.
# Processing Record 13  of Set 10 | pandan.
# City not found...skipping pandan.
# Processing Record 14  of Set 10 | puerto baquerizo moreno.
# City not found...skipping puerto baquerizo moreno.
# Processing Record 15  of Set 10 | cabo san lucas.
# City not found...skipping cabo san lucas.
# Processing Record 16  of Set 10 | kathwana.
# City not found...skipping kathwana.
# Processing Record 17  of Set 10 | gaigeturi.
# City not found...skipping gaigeturi.
# Processing Record 18  of Set 10 | usogorsk.
# City not found...skipping usogorsk.
# Processing Record 19  of Set 10 | syumsi.
# City not found...skipping syumsi.
# Processing Record 20  of Set 10 | riachao das neves.
# City not found...skipping riachao das neves.
# Processing Record 21  of Set 10 | khash.
# City not found...skipping khash.
# Processing Record 22  of Set 10 | willis.
# City not found...skipping willis.
# Processing Record 23  of Set 10 | ytyk-kyuyel'.
# City not found...skipping ytyk-kyuyel'.
# Processing Record 24  of Set 10 | basco.
# City not found...skipping basco.
# Processing Record 25  of Set 10 | codrington.
# City not found...skipping codrington.
# Processing Record 26  of Set 10 | loa janan.
# City not found...skipping loa janan.
# Processing Record 27  of Set 10 | grande prairie.
# City not found...skipping grande prairie.
# Processing Record 28  of Set 10 | nguigmi.
# City not found...skipping nguigmi.
# Processing Record 29  of Set 10 | takab.
# City not found...skipping takab.
# Processing Record 30  of Set 10 | vilyuysk.
# City not found...skipping vilyuysk.
# Processing Record 31  of Set 10 | pak phanang.
# City not found...skipping pak phanang.
# Processing Record 32  of Set 10 | bubaque.
# City not found...skipping bubaque.
# Processing Record 33  of Set 10 | hammerfest.
# City not found...skipping hammerfest.
# Processing Record 34  of Set 10 | richards bay.
# City not found...skipping richards bay.
# Processing Record 35  of Set 10 | genhe.
# City not found...skipping genhe.
# Processing Record 36  of Set 10 | klaksvik.
# City not found...skipping klaksvik.
# Processing Record 37  of Set 10 | mahavelona.
# City not found...skipping mahavelona.
# Processing Record 38  of Set 10 | terme.
# City not found...skipping terme.
# Processing Record 39  of Set 10 | pionerskiy.
# City not found...skipping pionerskiy.
# Processing Record 40  of Set 10 | lubuklinggau.
# City not found...skipping lubuklinggau.
# Processing Record 41  of Set 10 | tadine.
# City not found...skipping tadine.
# Processing Record 42  of Set 10 | bardaskan.
# City not found...skipping bardaskan.
# Processing Record 43  of Set 10 | san pedro pochutla.
# City not found...skipping san pedro pochutla.
# Processing Record 44  of Set 10 | medowie.
# City not found...skipping medowie.
# Processing Record 45  of Set 10 | magadan.
# City not found...skipping magadan.
# Processing Record 46  of Set 10 | ar rahad.
# City not found...skipping ar rahad.
# Processing Record 47  of Set 10 | nantucket.
# City not found...skipping nantucket.
# Processing Record 48  of Set 10 | sandakan.
# City not found...skipping sandakan.
# Processing Record 49  of Set 10 | garwolin.
# City not found...skipping garwolin.
# Processing Record 0  of Set 11 | vila velha.
# City not found...skipping vila velha.
# Processing Record 1  of Set 11 | qulsary.
# City not found...skipping qulsary.
# Processing Record 2  of Set 11 | port erin.
# City not found...skipping port erin.
# Processing Record 3  of Set 11 | muromtsevo.
# City not found...skipping muromtsevo.
# Processing Record 4  of Set 11 | trinity beach.
# City not found...skipping trinity beach.
# Processing Record 5  of Set 11 | miass.
# City not found...skipping miass.
# Processing Record 6  of Set 11 | zalingei.
# City not found...skipping zalingei.
# Processing Record 7  of Set 11 | karimnagar.
# City not found...skipping karimnagar.
# Processing Record 8  of Set 11 | gambiran satu.
# City not found...skipping gambiran satu.
# Processing Record 9  of Set 11 | kargopol'.
# City not found...skipping kargopol'.
# Processing Record 10  of Set 11 | borba.
# City not found...skipping borba.
# Processing Record 11  of Set 11 | shakawe.
# City not found...skipping shakawe.
# Processing Record 12  of Set 11 | shizuoka.
# City not found...skipping shizuoka.
# Processing Record 13  of Set 11 | ilomantsi.
# City not found...skipping ilomantsi.
# Processing Record 14  of Set 11 | muynoq.
# City not found...skipping muynoq.
# Processing Record 15  of Set 11 | stephenville.
# City not found...skipping stephenville.
# Processing Record 16  of Set 11 | smithers.
# City not found...skipping smithers.
# Processing Record 17  of Set 11 | northam.
# City not found...skipping northam.
# Processing Record 18  of Set 11 | mahina.
# City not found...skipping mahina.
# Processing Record 19  of Set 11 | soio.
# City not found...skipping soio.
# Processing Record 20  of Set 11 | jalai nur.
# City not found...skipping jalai nur.
# Processing Record 21  of Set 11 | cooma.
# City not found...skipping cooma.
# Processing Record 22  of Set 11 | masterton.
# City not found...skipping masterton.
# Processing Record 23  of Set 11 | solnechnyy.
# City not found...skipping solnechnyy.
# Processing Record 24  of Set 11 | camiri.
# City not found...skipping camiri.
# Processing Record 25  of Set 11 | tete.
# City not found...skipping tete.
# Processing Record 26  of Set 11 | vlore.
# City not found...skipping vlore.
# Processing Record 27  of Set 11 | villa de san diego de ubate.
# City not found...skipping villa de san diego de ubate.
# Processing Record 28  of Set 11 | homer.
# City not found...skipping homer.
# Processing Record 29  of Set 11 | gadzhiyevo.
# City not found...skipping gadzhiyevo.
# Processing Record 30  of Set 11 | port washington.
# City not found...skipping port washington.
# Processing Record 31  of Set 11 | poso.
# City not found...skipping poso.
# Processing Record 32  of Set 11 | nova vicosa.
# City not found...skipping nova vicosa.
# Processing Record 33  of Set 11 | xilitla.
# City not found...skipping xilitla.
# Processing Record 34  of Set 11 | riverside.
# City not found...skipping riverside.
# Processing Record 35  of Set 11 | holland.
# City not found...skipping holland.
# Processing Record 36  of Set 11 | tuy hoa.
# City not found...skipping tuy hoa.
# Processing Record 37  of Set 11 | peniche.
# City not found...skipping peniche.
# Processing Record 38  of Set 11 | kalix.
# City not found...skipping kalix.
# Processing Record 39  of Set 11 | prince albert.
# City not found...skipping prince albert.
# Processing Record 40  of Set 11 | cambria.
# City not found...skipping cambria.
# Processing Record 41  of Set 11 | ladismith.
# City not found...skipping ladismith.
# Processing Record 42  of Set 11 | yenotayevka.
# City not found...skipping yenotayevka.
# Processing Record 43  of Set 11 | walvis bay.
# City not found...skipping walvis bay.
# Processing Record 44  of Set 11 | selebi-phikwe.
# City not found...skipping selebi-phikwe.
# Processing Record 45  of Set 11 | taldykorgan.
# City not found...skipping taldykorgan.
# Processing Record 46  of Set 11 | iola.
# City not found...skipping iola.
# Processing Record 47  of Set 11 | kayangel.
# City not found...skipping kayangel.
# Processing Record 48  of Set 11 | al hudaydah.
# City not found...skipping al hudaydah.
# Processing Record 49  of Set 11 | piti village.
# City not found...skipping piti village.
# Processing Record 0  of Set 12 | bikenibeu village.
# City not found...skipping bikenibeu village.
# Processing Record 1  of Set 12 | nizhnyaya omka.
# City not found...skipping nizhnyaya omka.
# Processing Record 2  of Set 12 | hasaki.
# City not found...skipping hasaki.
# Processing Record 3  of Set 12 | chelbasskaya.
# City not found...skipping chelbasskaya.
# Processing Record 4  of Set 12 | broome.
# City not found...skipping broome.
# Processing Record 5  of Set 12 | agat village.
# City not found...skipping agat village.
# Processing Record 6  of Set 12 | castro.
# City not found...skipping castro.
# Processing Record 7  of Set 12 | boguchany.
# City not found...skipping boguchany.
# Processing Record 8  of Set 12 | gisborne.
# City not found...skipping gisborne.
# Processing Record 9  of Set 12 | spassk.
# City not found...skipping spassk.
# Processing Record 10  of Set 12 | otacilio costa.
# City not found...skipping otacilio costa.
# Processing Record 11  of Set 12 | san sebastian de la gomera.
# City not found...skipping san sebastian de la gomera.
# Processing Record 12  of Set 12 | rio claro.
# City not found...skipping rio claro.
# Processing Record 13  of Set 12 | port-de-paix.
# City not found...skipping port-de-paix.
# Processing Record 14  of Set 12 | igarka.
# City not found...skipping igarka.
# Processing Record 15  of Set 12 | junin de los andes.
# City not found...skipping junin de los andes.
# Processing Record 16  of Set 12 | grand falls-windsor.
# City not found...skipping grand falls-windsor.
# Processing Record 17  of Set 12 | yeed.
# City not found...skipping yeed.
# Processing Record 18  of Set 12 | chilaw.
# City not found...skipping chilaw.
# Processing Record 19  of Set 12 | beaver falls.
# City not found...skipping beaver falls.
# Processing Record 20  of Set 12 | andratx.
# City not found...skipping andratx.
# Processing Record 21  of Set 12 | ormara.
# City not found...skipping ormara.
# Processing Record 22  of Set 12 | gazojak.
# City not found...skipping gazojak.
# Processing Record 23  of Set 12 | vallenar.
# City not found...skipping vallenar.
# Processing Record 24  of Set 12 | mynamaki.
# City not found...skipping mynamaki.
# Processing Record 25  of Set 12 | mili.
# City not found...skipping mili.
# Processing Record 26  of Set 12 | mari-turek.
# City not found...skipping mari-turek.
# Processing Record 27  of Set 12 | tagiura.
# City not found...skipping tagiura.
# Processing Record 28  of Set 12 | sinjai.
# City not found...skipping sinjai.
# Processing Record 29  of Set 12 | harper.
# City not found...skipping harper.
# Processing Record 30  of Set 12 | naze.
# City not found...skipping naze.
# Processing Record 31  of Set 12 | oltinko'l.
# City not found...skipping oltinko'l.
# Processing Record 32  of Set 12 | pangkalpinang.
# City not found...skipping pangkalpinang.
# Processing Record 33  of Set 12 | tafuna.
# City not found...skipping tafuna.
# Processing Record 34  of Set 12 | xichang.
# City not found...skipping xichang.
# Processing Record 35  of Set 12 | yangquan.
# City not found...skipping yangquan.
# Processing Record 36  of Set 12 | ngorongoro.
# City not found...skipping ngorongoro.
# Processing Record 37  of Set 12 | hadibu.
# City not found...skipping hadibu.
# Processing Record 38  of Set 12 | paragominas.
# City not found...skipping paragominas.
# Processing Record 39  of Set 12 | thinadhoo.
# City not found...skipping thinadhoo.
# Processing Record 40  of Set 12 | malmberget.
# City not found...skipping malmberget.
# Processing Record 41  of Set 12 | ghat.
# City not found...skipping ghat.
# Processing Record 42  of Set 12 | de queen.
# City not found...skipping de queen.
# Processing Record 43  of Set 12 | at taj.
# City not found...skipping at taj.
# Processing Record 44  of Set 12 | i-n-salah.
# City not found...skipping i-n-salah.
# Processing Record 45  of Set 12 | frederikshavn.
# City not found...skipping frederikshavn.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
weather_df.sort_values(by='City', ascending=True)
weather_df.head()


# Show Record Count
weather_df.count()
# Out:
# City                596
# Country             596
# Date                596
# Latitude            596
# Longitude           596
# Cloudiness (%)      596
# Humidity (%)        596
# Max Temp (F)        596
# Wind Speed (mph)    596
# dtype: int64

# %%
# Display sample data
weather_df.head()
# Out:
#                           City Country Date Latitude Longitude Cloudiness (%)  \
# 0  edinburgh of the seven seas      SH      -37.0676  -12.3116             24
# 1                 port douglas      AU      -16.4833  145.4667             23
# 2            wailua homesteads      US       22.0669  -159.378            100
# 3                 invercargill      NZ         -46.4    168.35             68
# 4                    tranovaho
#
#   Humidity (%) Max Temp (F) Wind Speed (mph)
# 0           66       52.124            10.74
# 1           79       74.408             6.89
# 2           90       74.462             5.66
# 3           85        49.28             1.34
# 4

# %%
# Export the City_Data into a csv
weather_df.to_csv("D:/MSU DATA/Module6_challenge/Starter_Code/Starter_Code/output_data/cities.output.csv", index_label="City_ID")

# %%
# Read saved data
weather_df = pd.read_csv("D:/MSU DATA/Module6_challenge/Starter_Code/Starter_Code/output_data/cities.output.csv", index_col="City_ID")

# Display sample data
weather_df.head()
# Out:
#                                 City Country  Date  Latitude  Longitude  \
# City_ID
# 0        edinburgh of the seven seas      SH   NaN  -37.0676   -12.3116
# 1                       port douglas      AU   NaN  -16.4833   145.4667
# 2                  wailua homesteads      US   NaN   22.0669  -159.3780
# 3                       invercargill      NZ   NaN  -46.4000   168.3500
# 4                          tranovaho     NaN   NaN       NaN        NaN
#
#          Cloudiness (%)  Humidity (%)  Max Temp (F)  Wind Speed (mph)
# City_ID
# 0                  24.0          66.0        52.124             10.74
# 1                  23.0          79.0        74.408              6.89
# 2                 100.0          90.0        74.462              5.66
# 3                  68.0          85.0        49.280              1.34
# 4                   NaN           NaN           NaN               NaN

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Max Temp (F)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Max Latitude vs  Temperature ({today})")
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Humidity (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity ({today})")
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness

today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({today})")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({today})")
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
northern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) < 0, :]

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_df
# Out:
#                       City Country  Date  Latitude  Longitude  Cloudiness (%)  \
# City_ID
# 2        wailua homesteads      US   NaN   22.0669  -159.3780           100.0
# 5                 fisterra      ES   NaN   42.9049    -9.2629            99.0
# 6                 ust-nera      RU   NaN   64.5667   143.2000            30.0
# 9                  selfoss      IS   NaN   63.9331   -20.9971            12.0
# 10                  phayao      TH   NaN   19.2500   100.2500           100.0
# ...                    ...     ...   ...       ...        ...             ...
# 591                   ghat      LY   NaN   24.9647    10.1728             1.0
# 592               de queen      US   NaN   34.0379   -94.3413           100.0
# 593                 at taj      LY   NaN   24.2049    23.2857            50.0
# 594              i-n-salah      DZ   NaN   27.1935     2.4607            47.0
# 595          frederikshavn      DK   NaN   57.4407    10.5366           100.0
#
#          Humidity (%)  Max Temp (F)  Wind Speed (mph)
# City_ID
# 2                90.0        74.462              5.66
# 5                70.0        58.010             12.35
# 6                98.0        -0.220              1.04
# 9                70.0        27.320              3.12
# 10               95.0        76.802              1.15
# ...               ...           ...               ...
# 591              14.0        89.870              3.11
# 592             100.0        70.286              0.00
# 593              19.0        85.712              2.73
# 594              12.0        93.488              2.73
# 595              89.0        45.212             13.04
#
# [393 rows x 9 columns]

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# Display sample data
southern_df
# Out:
#                                 City Country  Date  Latitude  Longitude  \
# City_ID
# 0        edinburgh of the seven seas      SH   NaN  -37.0676   -12.3116
# 1                       port douglas      AU   NaN  -16.4833   145.4667
# 3                       invercargill      NZ   NaN  -46.4000   168.3500
# 7                          adamstown      PN   NaN  -25.0660  -130.1015
# 8                               kone      NC   NaN  -21.0595   164.8658
# ...                              ...     ...   ...       ...        ...
# 578                           sinjai      ID   NaN   -5.1241   120.2530
# 582                    pangkalpinang      ID   NaN   -2.1333   106.1333
# 583                           tafuna      AS   NaN  -14.3358  -170.7200
# 586                       ngorongoro      TZ   NaN   -3.2397    35.4875
# 588                      paragominas      BR   NaN   -2.9667   -47.4833
#
#          Cloudiness (%)  Humidity (%)  Max Temp (F)  Wind Speed (mph)
# City_ID
# 0                  24.0          66.0        52.124             10.74
# 1                  23.0          79.0        74.408              6.89
# 3                  68.0          85.0        49.280              1.34
# 7                 100.0          85.0        72.428              6.77
# 8                  30.0          69.0        67.802              2.04
# ...                 ...           ...           ...               ...
# 578                56.0          72.0        80.150              2.45
# 582                38.0          65.0        85.442              4.43
# 583                75.0         100.0        75.416              0.00
# 586                52.0          41.0        71.672              4.08
# 588                41.0          83.0        77.000              3.03
#
# [177 rows x 9 columns]

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.8692641499048683

# %%
# Linear regression on Southern Hemisphere
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# The r-squared is: 0.791599180746492

# %% [markdown]
# **Discussion about the linear relationship:** The scatter plot maps Southern Hemisphere and Max temperature against their latitude. Cities selected randomly.
#
# The result reveals a strong correlation between distance from the equator temperature. The closer to the equator, the higher the temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = 0.22x + 61.1
# The r-squared is: 0.18634264614016466
# The regression does not display much of a correlation between the data sets.

# %%
# Southern Hemisphere

x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = -0.01x + 67.7
# The r-squared is: -0.004154450044618545
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# **Discussion about the linear relationship:** The scatter plot maps southern Hemisphere and Southern cities' Humidity against their latitude. Cities selected randomly.
#
# The result reveals a strong correlation between distance from the equator Humidity. The farther to the equator, the higher the Humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# Regression line equation is: y = 0.19x + 51.16
# The r-squared is: 0.09209339571992055

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# Regression line equation is: y = -0.39x + 47.91
# The r-squared is: -0.15317517604266256
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# **Discussion about the linear relationship:** The scatter plot maps Northern Hemisphere and Southern cities' cloudiness against their latitude. Cities selected randomly.
#
# The result reveals a strong correlation between distance from the equator cloudiness. The farther to the equator, the higher the cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# Regression line equation is: y = 0.01x + 3.18
# The r-squared is: 0.07137231694444163

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# Regression line equation is: y = -0.04x + 3.55
# The r-squared is: -0.20883281786559105

# %% [markdown]
# **Discussion about the linear relationship:** The scatter plot maps Northern Hemisphere and Southern cities' Windspeed against their latitude. Cities selected randomly.
#
# The result reveals a strong correlation between distance from the equator Windspeed. The farther to the equator, the higher the Windspeed.
